# %% [markdown]
# # EPLORATORY DATA ANALYSIS
# ------

# %% [markdown]
# **Abiyyu Fathin Derian**
#
# **IYKRA Data Fellowship Batch 6**

# %% [markdown]
# -----
# ## Import Library

# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt

# %% [markdown]
# ------
# ## Load The Dataset

# %%
# Get the dataset
dataset = pd.read_csv('epl_1819.csv')

# Check the 5 first value
dataset.head()
# Out:
#               Team                        category  general_league_position  \
# 0  Manchester City                Champions League                        1
# 1        Liverpool                Champions League                        2
# 2          Chelsea  Champions League Qualification                        3
# 3        Tottenham  Champions League Qualification                        4
# 4          Arsenal                   Europa League                        5
#
#    finance _live_games_televised  finance _tv_revenue  general_matches_played  \
# 0                             26            150986355                      38
# 1                             29            152425146                      38
# 2                             25            146030216                      38
# 3                             26            145230801                      38
# 4                             25            142193180                      38
#
# ...

# %%
# Check the 5 last value
dataset.tail()
# Out:
#             Team              category  general_league_position  \
# 15   Southampton  No UEFA Competitions                       16
# 16      Brighton  No UEFA Competitions                       17
# 17       Cardiff             Relegated                       18
# 18        Fulham             Relegated                       19
# 19  Huddersfield             Relegated                       20
#
#     finance _live_games_televised  finance _tv_revenue  \
# 15                             10            104302937
# 16                             13            105741728
# 17                             12            102704107
# 18                             13            101904692
# 19                             10             96628865
#
#     general_matches_played  general_won  general_draw  general_lost  \
# 15                      38            9            12            17
# 16                      38            9             9            20
# ...

# %% [markdown]
# ------
# ## Data Understanding

# %%
# Check the dimension of the dataset
dataset.shape
# Out:
# (20, 44)

# %%
# Check the columns' name
dataset.columns
# Out:
# Index(['Team', 'category', 'general_league_position',
#        'finance _live_games_televised', 'finance _tv_revenue',
#        'general_matches_played', 'general_won', 'general_draw', 'general_lost',
#        'attack_scored', 'defence_goals_conceeded', 'general_goal_difference',
#        'general_points', 'general_squad_size', 'general_squad_average_age',
#        'general_squad_foreigners', 'finance _team_market',
#        'finance _market_average', 'attack_passes', 'attack_passes_through',
#        'attack_passes_long', 'attack_passes_back', 'attack_crosses',
#        'attack_corners_taken', 'attack_shots', 'attack_shots_on_target',
#        'attack_goals_headed', 'attack_goals_penalty', 'attack_goals_box',
#        'attack_goals_outsidebox', 'general_card_yellow', 'general_card_red',
#        'attack_goals_counter', 'attack_goals_freekick', 'defence_saves',
#        'defence_blocks', 'defence_interceptions', 'defence_tackles',
# ...

# %%
# Check the brief information of basic statistics
dataset.describe()
# Out:
#        general_league_position  finance _live_games_televised  \
# count                 20.00000                      20.000000
# mean                  10.50000                      17.100000
# std                    5.91608                       6.734827
# min                    1.00000                      10.000000
# 25%                    5.75000                      11.750000
# 50%                   10.50000                      15.000000
# 75%                   15.25000                      25.000000
# max                   20.00000                      29.000000
#
#        finance _tv_revenue  general_matches_played  general_won  general_draw  \
# count         2.000000e+01                    20.0    20.000000      20.00000
# mean          1.228004e+08                    38.0    15.450000       7.10000
# std           1.821686e+07                     0.0     7.250953       2.44734
# min           9.662886e+07                    38.0     3.000000       2.00000
# ...

# %%
# Check the brief information of the dataset
dataset.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 20 entries, 0 to 19
# Data columns (total 44 columns):
#  #   Column                         Non-Null Count  Dtype
# ---  ------                         --------------  -----
#  0   Team                           20 non-null     object
#  1   category                       20 non-null     object
#  2   general_league_position        20 non-null     int64
#  3   finance _live_games_televised  20 non-null     int64
#  4   finance _tv_revenue            20 non-null     int64
#  5   general_matches_played         20 non-null     int64
#  6   general_won                    20 non-null     int64
#  7   general_draw                   20 non-null     int64
#  8   general_lost                   20 non-null     int64
#  9   attack_scored                  20 non-null     int64
#  10  defence_goals_conceeded        20 non-null     int64
#  11  general_goal_difference        20 non-null     int64
# ...

# %%
# Check the total of unique value of each column
dataset.nunique()
# Out:
# Team                             20
# category                          6
# general_league_position          20
# finance _live_games_televised    12
# finance _tv_revenue              20
# general_matches_played            1
# general_won                      15
# general_draw                      8
# general_lost                     13
# attack_scored                    16
# defence_goals_conceeded          17
# general_goal_difference          20
# general_points                   18
# general_squad_size                7
# general_squad_average_age        16
# general_squad_foreigners         12
# finance _team_market             20
# finance _market_average          20
# attack_passes                    20
# attack_passes_through            19
# attack_passes_long               20
# attack_passes_back               20
# attack_crosses                   20
# attack_corners_taken             19
# attack_shots                     19
# attack_shots_on_target           19
# ...

# %%
# Check the duplicated value
dataset.duplicated()
# Out:
# 0     False
# 1     False
# 2     False
# 3     False
# 4     False
# 5     False
# 6     False
# 7     False
# 8     False
# 9     False
# 10    False
# 11    False
# 12    False
# 13    False
# 14    False
# 15    False
# 16    False
# 17    False
# 18    False
# 19    False
# dtype: bool

# %% [markdown]
# ### Check The Data Inspected as Type object rather than int64

# %%
# Check the data value
dataset[['attack_passes', 'attack_passes_long', 'attack_passes_back', 'defence_clearances']]
# Out:
#    attack_passes attack_passes_long attack_passes_back defence_clearances
# 0         26,581              1,814              4,240                543
# 1         23,638              2,250              3,416                639
# 2         25,070              1,774              3,874                593
# 3         21,295              2,267              3,191                770
# 4         20,805              2,062              3,102                762
# 5         19,202              2,242              2,634                785
# 6         16,618              2,552              2,515                824
# 7         16,494              2,310              2,362                825
# 8         17,219              2,335              2,593                945
# 9         16,358              2,315              2,273                855
# 10        15,462              2,437              2,314                956
# 11        15,243              2,259              2,233                940
# ...

# %% [markdown]
# Based on the inspection, we know that the data is numeric, but they are typed as object. Therefore, in the Data Preprocessing, we will convert the data type of those columns into int64.

# %% [markdown]
# ### Checking Missing Value

# %%
# Check the total missing value of each column
dataset.isna().sum()
# Out:
# Team                             0
# category                         0
# general_league_position          0
# finance _live_games_televised    0
# finance _tv_revenue              0
# general_matches_played           0
# general_won                      0
# general_draw                     0
# general_lost                     0
# attack_scored                    0
# defence_goals_conceeded          0
# general_goal_difference          0
# general_points                   0
# general_squad_size               0
# general_squad_average_age        0
# general_squad_foreigners         0
# finance _team_market             0
# finance _market_average          0
# attack_passes                    0
# attack_passes_through            0
# attack_passes_long               0
# attack_passes_back               0
# attack_crosses                   0
# attack_corners_taken             0
# attack_shots                     0
# attack_shots_on_target           0
# attack_goals_headed              0
# ...

# %% [markdown]
# Because there is no missing value, then we do not need to impute missing value in the Data Preprocessing

# %% [markdown]
# -------
# ## Data Preprocessing

# %% [markdown]
# ### Convert The Type of 'attack_passes', 'attack_passes_long', 'attack_passes_back', and 'defence_clearances' columns

# %% [markdown]
# Because all of them are numerical data, then we will convert them into int64 datatype.

# %%
# Convert datatype form object to int
dataset[['attack_passes', 'attack_passes_long', 'attack_passes_back', 'defence_clearances']] = dataset[['attack_passes', 'attack_passes_long', 'attack_passes_back', 'defence_clearances']].apply(lambda x: x.str.replace(',','')).apply(lambda x: x.astype('int'))
dataset[['attack_passes', 'attack_passes_long', 'attack_passes_back', 'defence_clearances']]
# Out:
#     attack_passes  attack_passes_long  attack_passes_back  defence_clearances
# 0           26581                1814                4240                 543
# 1           23638                2250                3416                 639
# 2           25070                1774                3874                 593
# 3           21295                2267                3191                 770
# 4           20805                2062                3102                 762
# 5           19202                2242                2634                 785
# 6           16618                2552                2515                 824
# 7           16494                2310                2362                 825
# 8           17219                2335                2593                 945
# 9           16358                2315                2273                 855
# 10          15462                2437                2314                 956
# ...

# %%
# Check the datatype
dataset[['attack_passes', 'attack_passes_long', 'attack_passes_back', 'defence_clearances']].dtypes
# Out:
# attack_passes         int64
# attack_passes_long    int64
# attack_passes_back    int64
# defence_clearances    int64
# dtype: object

# %% [markdown]
# -------
# ## Asked Questions

# %% [markdown]
# ### 1. Is this data clean?

# %% [markdown]
# **Answer:**

# %% [markdown]
# Based on the step in **Data Understanding**, we know that the data is explained below:
# 1. There is no missing value
# 2. There is no duplicated value
# Thus, we can say that **the data is clean**.
#
# However, when we inspect the datatype, we got that several columns containing numerical value is stated as object rather than int64 datatype. Therefore, we have to convert those data into its int64 datatype. Even though some columns' datatype is not suitable, I still say that basically **the data itself is clean**.

# %% [markdown]
# ### 2. How is the point distribution of the epl team? And which team is an anomaly?

# %% [markdown]
# **Answer:**

# %% [markdown]
# To answer this question, I will use field/column 'general_points' as the reference. I will use Histogram to see the distribution of the data and use Outliers from Quantile distribution to inspect the team that is anomaly.

# %% [markdown]
# ### Inspect The Distribution using Histogram

# %% [markdown]
# The reason I use Histogram for this distribution inspection because the data is only single variable.

# %%
# Check the distribution using histogram
sns.displot(x = 'general_points', data = dataset, kde = True)

# %% [markdown]
# From the histogram, we can see that the 7 out of 20 teams have general_points between 40 - 60, and only 2 out of 20 teams that have general_points between 80 - 100.

# %% [markdown]
# ### Inspect The Anomaly of The Team

# %% [markdown]
# To do this, we will inspect the outliers of the data by the following step

# %%
# Check the outliers of the data
Upper_outlier = []
Lower_outlier = []

Q1 = dataset['general_points'].quantile(0.25)
Q3 = dataset['general_points'].quantile(0.75)
IQR = Q3 - Q1
Upper = Q3 + (1.5*IQR)
Lower = Q1 - (1.5*IQR)

for x in dataset['general_points']:
    if (x > Upper):
        print(x)
    elif (x < Lower):
        print(x)
    else:
        print('There is no outliers')
# Out:
# There is no outliers
# There is no outliers
# There is no outliers
# There is no outliers
# There is no outliers
# There is no outliers
# There is no outliers
# There is no outliers
# There is no outliers
# There is no outliers
# There is no outliers
# There is no outliers
# There is no outliers
# There is no outliers
# There is no outliers
# There is no outliers
# There is no outliers
# There is no outliers
# There is no outliers
# There is no outliers

# %% [markdown]
# We found that there is no outliers data. Therefore, we can say that there is no theam that is anomaly.

# %% [markdown]
# ### 3. Which team has the best attack?

# %% [markdown]
# **Answer:**

# %% [markdown]
# First of all, to know the team has the best attack, I will select all columns that contribute the attacking of the team, they are stated below:
# - attack_scored
# - attack_passes
# - attack_passes_through
# - attack_passes_long
# - attack_passes_back
# - attack_crosses
# - attack_corners_taken
# - attack_shots
# - attack_shots_on_target
# - attack_goals_headed
# - attack_goals_penalty
# - attack_goals_box
# - attack_goals_outsidebox
# - attack_goals_counter
# - attack_goals_freekick
# - attack_posession
# - attack_pass_accuracy

# %%
# Get the columns that contains attack keyword
attack_dataset = dataset[['Team', 'attack_scored', 'attack_passes', 'attack_passes_through', 'attack_passes_long',
                          'attack_passes_back', 'attack_crosses', 'attack_corners_taken', 'attack_shots',
                          'attack_shots_on_target', 'attack_goals_headed', 'attack_goals_penalty', 
                          'attack_goals_box', 'attack_goals_outsidebox', 'attack_goals_counter', 
                          'attack_goals_freekick', 'attack_posession', 'attack_pass_accuracy']]
attack_dataset.head()
# Out:
#               Team  attack_scored  attack_passes  attack_passes_through  \
# 0  Manchester City             95          26581                    112
# 1        Liverpool             89          23638                     98
# 2          Chelsea             63          25070                    146
# 3        Tottenham             67          21295                     87
# 4          Arsenal             73          20805                     65
#
#    attack_passes_long  attack_passes_back  attack_crosses  \
# 0                1814                4240             783
# 1                2250                3416             721
# 2                1774                3874             692
# 3                2267                3191             643
# 4                2062                3102             605
#
#    attack_corners_taken  attack_shots  attack_shots_on_target  \
# 0                   298           683                     260
# ...

# %% [markdown]
# Cited from https://www.guidetofootball.com/tactics/attacking-objectives/ and http://recentfootballnews.com/attacking-an-overview/, the most crucial factors to determine the best attack of the team are:
#
# - **Goal effectiveness**, defines as the conversion of the goal chance into the goal. It can be considered by the total goal and the shot on target
# - **Ball possesion**, defines as the combination of dribbling and passing that can prevent the opposite team to has a chance to score a goal
# - **Penetration**, defines as the effectiveness of the passing during the game and its accuracy of the passing itself
#
# Therefore, I created some new columns that represents those factors, they are:
# - '%goal_converted', defines as the comparation of total goal (sum of 'attack_goals_headed', 'attack_goals_penalty', 'attack_goals_box', 'attack_goals_outsidebox', 'attack_goals_counter', 'attack_goals_freekick') to 'attack_shots_on_target', as the representatives of Goal effectiveness' factor
# - '%attack_passes_corner_cross', defines as the comparation of all passing interaction (sum of 'attack_passes_through', 'attack_passes_long', 'attack_passes_back', 'attack_crosses', 'attack_corners_taken') to 'attack_passes', as the representative of Penetration's factor
#
# Thus, to cover all of the factors, I created a new table that contains 4 columns, they are '%goal_converted', '%attack_passes_corner_cross', 'attack_posession', 'attack_pass_accuracy'.
#
# Basically, those 4 columns are required. For '%goal_converted', 'attack_posession', 'attack_pass_accuracy' columns, the bigger the value, the better is the result. Meanwhile for the '%attack_passes_corner_cross', the smaller the value, the better the result.

# %% [markdown]
# ### Created New Columns of '%goal_converted' and '%attack_passes_corner_cross'

# %%
# Create the '%attack_passes_corner_cross' column
attack_dataset['%attack_passes_corner_cross'] = ((attack_dataset['attack_passes_through'] + 
                                     attack_dataset['attack_passes_long'] + 
                                     attack_dataset['attack_passes_back'] +
                                     attack_dataset['attack_crosses'] + 
                                     attack_dataset['attack_corners_taken'])/attack_dataset['attack_passes'])*100
attack_dataset['%attack_passes_corner_cross']
# Out:
# <ipython-input-161-2288dbdb0304>:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   attack_dataset['%attack_passes_corner_cross'] = ((attack_dataset['attack_passes_through'] +
# 0     27.263835
# 1     28.488028
# 2     26.729158
# 3     29.969476
# 4     29.045902
# 5     30.085408
# 6     35.714286
# 7     34.830848
# 8     34.874267
# 9     33.506541
# 10    35.765102
# 11    34.770058
# 12    41.667902
# 13    31.625165
# 14    44.669895
# 15    37.252570
# 16    38.996385
# 17    45.961275
# 18    33.742019
# 19    38.039240
# Name: %attack_passes_corner_cross, dtype: float64

# %%
# Create the '%goal_converted' column
attack_dataset['total_goal'] = (attack_dataset['attack_goals_headed'] + 
                                 attack_dataset['attack_goals_penalty'] + 
                                 attack_dataset['attack_goals_box'] + 
                                 attack_dataset['attack_goals_outsidebox'] + 
                                 attack_dataset['attack_goals_counter'] + 
                                 attack_dataset['attack_goals_freekick'])
attack_dataset['%goal_converted'] = (attack_dataset['total_goal']/attack_dataset['attack_shots_on_target'])*100
attack_dataset['%goal_converted']
# Out:
# <ipython-input-162-7fc0a0e1fdea>:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   attack_dataset['total_goal'] = (attack_dataset['attack_goals_headed'] +
# <ipython-input-162-7fc0a0e1fdea>:8: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   attack_dataset['%goal_converted'] = (attack_dataset['total_goal']/attack_dataset['attack_shots_on_target'])*100
# 0     45.000000
# 1     53.982301
# 2     39.393939
# 3     48.677249
# 4     51.764706
# 5     37.333333
# 6     44.736842
# 7     43.195266
# ...

# %% [markdown]
# ### Generate The New Table

# %%
# Create a new variable of selected columns
attack_dataset_fix = attack_dataset[['Team', '%goal_converted', 'attack_posession', '%attack_passes_corner_cross', 'attack_pass_accuracy']]
attack_dataset_fix
# Out:
#                  Team  %goal_converted  attack_posession  \
# 0     Manchester City        45.000000              64.0
# 1           Liverpool        53.982301              58.8
# 2             Chelsea        39.393939              59.9
# 3           Tottenham        48.677249              56.7
# 4             Arsenal        51.764706              56.1
# 5   Manchester United        37.333333              53.3
# 6       Wolverhampton        44.736842              47.4
# 7             Everton        43.195266              51.0
# 8           Leicester        41.304348              50.8
# 9            West Ham        44.585987              49.0
# 10            Watford        42.105263              47.4
# 11     Crystal Palace        47.297297              46.6
# 12          Newcastle        40.140845              42.9
# 13        Bournemouth        50.920245              47.7
# 14            Burnley        52.586207              43.4
# ...

# %% [markdown]
# ### Calculate The Mean of selected columns

# %%
# Count the mean value
attack_dataset_fix['%mean_attacking'] = attack_dataset_fix[['%goal_converted', 'attack_posession', 'attack_pass_accuracy']].mean(axis=1)
attack_dataset_fix.head()
# Out:
# <ipython-input-172-80ef61be767b>:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   attack_dataset_fix['%mean_attacking'] = attack_dataset_fix[['%goal_converted', 'attack_posession', 'attack_pass_accuracy']].mean(axis=1)
#               Team  %goal_converted  attack_posession  \
# 0  Manchester City        45.000000              64.0
# 1        Liverpool        53.982301              58.8
# 2          Chelsea        39.393939              59.9
# 3        Tottenham        48.677249              56.7
# 4          Arsenal        51.764706              56.1
#
#    %attack_passes_corner_cross  attack_pass_accuracy  mean_attacking  \
# 0                    27.263835                  89.0       66.000000
# ...

# %%
# Select only the final columns
attack_dataset_fixed = attack_dataset_fix[['Team', '%mean_attacking', '%attack_passes_corner_cross']]
attack_dataset_fixed.head()
# Out:
#               Team  %mean_attacking  %attack_passes_corner_cross
# 0  Manchester City        66.000000                    27.263835
# 1        Liverpool        65.727434                    28.488028
# 2          Chelsea        62.297980                    26.729158
# 3        Tottenham        62.859083                    29.969476
# 4          Arsenal        63.721569                    29.045902

# %%
# Create scatter plot
fig, ax = plt.subplots(figsize=(20,15))

sns.scatterplot(data = attack_dataset_fixed, x = "%mean_attacking", 
                y = "%attack_passes_corner_cross", s = 200, ax = ax,
                hue = attack_dataset_fixed['Team']).set(title = 'Mean_Attacking vs Attacking_Passess_Corner')
# Out:
# [Text(0.5, 1.0, 'Mean_Attacking vs Attacking_Passess_Corner')]

# %% [markdown]
# ### Show The best attacking team

# %%
# Get the max value
#attack_dataset_fix[attack_dataset_fix['%mean_attacking'] == attack_dataset_fix['%mean_attacking'].max()][['Team','%mean_attacking', '%attack_passes_corner_cross']]

attack_dataset_fixed[attack_dataset_fixed['Team'] == 'Manchester City']
# Out:
#               Team  %mean_attacking  %attack_passes_corner_cross
# 0  Manchester City             66.0                    27.263835

# %% [markdown]
# ### 4. Which team has the best defence?

# %% [markdown]
# **Answer:**

# %% [markdown]
# First of all, to know the team has the best defence, I will select all columns that contribute the defending of the team, they are stated below:
#
# - defence_saves
# - defence_blocks
# - defence_interceptions
# - defence_tackles
# - defence_tackles_last_man
# - defence_clearances
# - defence_clearances_headed
# - defence_penalty_conceeded

# %%
# Get the columns that contains attack keyword
defence_dataset = dataset[['Team', 'defence_saves', 'defence_blocks', 'defence_interceptions', 'defence_tackles',
                           'defence_tackles_last_man', 'defence_clearances', 'defence_clearances_headed',
                           'defence_penalty_conceeded', 'general_goal_difference']]
defence_dataset.head()
# Out:
#               Team  defence_saves  defence_blocks  defence_interceptions  \
# 0  Manchester City             58              63                    362
# 1        Liverpool             76              78                    314
# 2          Chelsea             85              73                    351
# 3        Tottenham            121             112                    326
# 4          Arsenal            133             118                    412
#
#    defence_tackles  defence_tackles_last_man  defence_clearances  \
# 0              518                         0                 543
# 1              610                         2                 639
# 2              618                         2                 593
# 3              626                         3                 770
# 4              609                         2                 762
#
#    defence_clearances_headed  defence_penalty_conceeded  \
# 0                        295                          4
# ...

# %% [markdown]
# Cited from https://completesoccerguide.com/soccer-defender/, the most crucial factors to determine the best defence of the team are:
#
# - **Overlap and cover**, defines as the effort to stop opposite team while attacking
# - **Clear the ball**, defines as the ability of team to failed a goal from opposite team
#
# Therefore, I selected some columns that represents those factors, they are:
# - 'defence_saves' and 'defence_blocks', as the representatives of Clear the ball factor
# - 'defence_interceptions', 'defence_tackles', 'defence_clearances', as the representative of Overlap and cover factor
#
# For 'general_goal_difference' column, the bigger the value, the better is the result. Meanwhile for the 'defence_saves', 'defence_blocks', 'defence_interceptions', 'defence_tackles', 'defence_clearances', the smaller the value, the better the result. But, because I am confused how to analyze that inversed data, that is why I only choose to use the maximum value of average of 'defence_saves', 'defence_blocks', 'defence_interceptions', 'defence_tackles', 'defence_clearances'.

# %% [markdown]
# ### Generate The New Table

# %%
# Create a new variable of selected columns
defence_dataset_fix = defence_dataset[['Team', 'defence_saves', 'defence_blocks', 'defence_interceptions', 'defence_tackles', 'defence_clearances', 'general_goal_difference']]
defence_dataset_fix.head()
# Out:
#               Team  defence_saves  defence_blocks  defence_interceptions  \
# 0  Manchester City             58              63                    362
# 1        Liverpool             76              78                    314
# 2          Chelsea             85              73                    351
# 3        Tottenham            121             112                    326
# 4          Arsenal            133             118                    412
#
#    defence_tackles  defence_clearances  general_goal_difference
# 0              518                 543                       72
# 1              610                 639                       67
# 2              618                 593                       24
# 3              626                 770                       28
# 4              609                 762                       22

# %% [markdown]
# ### Count The Average of 'defence_saves', 'defence_blocks', 'defence_interceptions', 'defence_tackles', 'defence_clearances'

# %%
# Count the mean value
defence_dataset_fix['%mean_defence'] = defence_dataset[['defence_saves', 'defence_blocks', 'defence_interceptions', 'defence_tackles', 'defence_clearances']].mean(axis=1)
defence_dataset_fix.head()
# Out:
# <ipython-input-200-94ca186fef6c>:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   defence_dataset_fix['%mean_defence'] = defence_dataset[['defence_saves', 'defence_blocks', 'defence_interceptions', 'defence_tackles', 'defence_clearances']].mean(axis=1)
#               Team  defence_saves  defence_blocks  defence_interceptions  \
# 0  Manchester City             58              63                    362
# 1        Liverpool             76              78                    314
# 2          Chelsea             85              73                    351
# 3        Tottenham            121             112                    326
# 4          Arsenal            133             118                    412
#
# ...

# %%
'''
# Select only the final columns
defence_dataset_fixed = defence_dataset_fix[['Team', '%mean_defence', 'general_goal_difference']]
defence_dataset_fixed.head()
'''
# Out:
# "\n# Select only the final columns\ndefence_dataset_fixed = defence_dataset_fix[['Team', '%mean_defence', 'general_goal_difference']]\ndefence_dataset_fixed.head()\n"

# %%
'''
# Create scatter plot
sns.scatterplot(data = defence_dataset_fixed, x="general_goal_difference", y="%mean_defence", hue = 'Team')
plt.legend(bbox_to_anchor = (1.02, 1), loc='upper left', borderaxespad=0)
'''
# Out:
# '\n# Create scatter plot\nsns.scatterplot(data = defence_dataset_fixed, x="general_goal_difference", y="%mean_defence", hue = \'Team\')\nplt.legend(bbox_to_anchor = (1.02, 1), loc=\'upper left\', borderaxespad=0)\n'

# %% [markdown]
# ### Show The best defence team

# %%
# Select only the final columns
defence_dataset_fix[defence_dataset_fix['%mean_defence'] == defence_dataset_fix['%mean_defence'].max()][['Team','%mean_defence']]
# Out:
#            Team  %mean_defence
# 15  Southampton          516.4

# %% [markdown]
# ### 5. Which team is good in the financial aspect?

# %% [markdown]
# **Answer:**

# %% [markdown]
# First of all, to know the team is good in the financial aspect, I will select all columns that relate to the financial aspect, they are stated below:
#
# - finance _live_games_televised
# - finance _tv_revenue
# - finance _team_market
# - finance _market_average

# %%
# Get the columns that contains attack keyword
finance_dataset = dataset[['Team', 'finance _live_games_televised', 'finance _tv_revenue', 'finance _team_market', 'finance _market_average']]
finance_dataset.head()
# Out:
#               Team  finance _live_games_televised  finance _tv_revenue  \
# 0  Manchester City                             26            150986355
# 1        Liverpool                             29            152425146
# 2          Chelsea                             25            146030216
# 3        Tottenham                             26            145230801
# 4          Arsenal                             25            142193180
#
#    finance _team_market  finance _market_average
# 0            1003200000                 39987200
# 1             836440000                 34848000
# 2             779460000                 29981600
# 3             735240000                 29409600
# 4             701800000                 26989600

# %% [markdown]
# Cited from https://sites.duke.edu/wcwp/research-projects/mediamarketsfootball-in-contemporary-europe/the-money/, I found that there are two factor that can impact the financial aspects, they are:
#
# - **Revenue of the club**, defines as the revenue that is reached by the team
# - **Spend of the Club**, defines as the expenditure of the team
#
# Therefore, I selected some columns that represents those factors, they are:
# - 'finance _tv_revenue' , as the representatives of Revenue of the club factor
# - 'finance _market_average', as the representative of Spend of the Club factor. I assume like this because there is no data dictionary that explain it more detail
#
# The best finance team is the team that has high 'finance _tv_revenue' and low 'finance _market_average'. It is because the used columns are the liquid money, not only an asset. Therefore, **I substacted both of them, then get the maximum value**. And I also add parameter that the best finance clubs are the team who successfully got a chance to join **Champions League Qualification**.

# %% [markdown]
# ### Generate The New Table

# %%
# Get the new suitable columns
finance_dataset_fix = dataset[['Team', 'category', 'finance _tv_revenue', 'finance _market_average']]
finance_dataset_fix.head()
# Out:
#               Team                        category  finance _tv_revenue  \
# 0  Manchester City                Champions League            150986355
# 1        Liverpool                Champions League            152425146
# 2          Chelsea  Champions League Qualification            146030216
# 3        Tottenham  Champions League Qualification            145230801
# 4          Arsenal                   Europa League            142193180
#
#    finance _market_average
# 0                 39987200
# 1                 34848000
# 2                 29981600
# 3                 29409600
# 4                 26989600

# %%
# Substract the value
finance_dataset_fix['gap_of_revenue'] = finance_dataset_fix['finance _tv_revenue'] - finance_dataset_fix['finance _market_average']
finance_dataset_fix.head()
# Out:
# <ipython-input-233-3e6a03894f3a>:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   finance_dataset_fix['gap_of_revenue'] = finance_dataset_fix['finance _tv_revenue'] - finance_dataset_fix['finance _market_average']
#               Team                        category  finance _tv_revenue  \
# 0  Manchester City                Champions League            150986355
# 1        Liverpool                Champions League            152425146
# 2          Chelsea  Champions League Qualification            146030216
# 3        Tottenham  Champions League Qualification            145230801
# 4          Arsenal                   Europa League            142193180
#
#    finance _market_average  gap_of_revenue
# ...

# %% [markdown]
# ### Select The Required Columns

# %%
# Select the columns
finance_dataset_fixed = finance_dataset_fix[['Team', 'category', 'gap_of_revenue']]

# %% [markdown]
# ### Select Columns that only Champion League Qualification

# %%
# Get data that only Champion League Qualification
finance_dataset_fixed = finance_dataset_fixed.loc[(finance_dataset_fixed['category'] == 'Champions League') | 
                        (finance_dataset_fixed['category'] == 'Champions League Qualification')]
finance_dataset_fixed
# Out:
#               Team                        category  gap_of_revenue
# 0  Manchester City                Champions League       110999155
# 1        Liverpool                Champions League       117577146
# 2          Chelsea  Champions League Qualification       116048616
# 3        Tottenham  Champions League Qualification       115821201

# %% [markdown]
# ### Get The Best Finance Aspect Team

# %%
finance_dataset_fixed[finance_dataset_fixed['gap_of_revenue'] == finance_dataset_fixed['gap_of_revenue'].
                      max()][['Team','category', 'gap_of_revenue']]
# Out:
#         Team          category  gap_of_revenue
# 1  Liverpool  Champions League       117577146

# %% [markdown]
# ### 6. Having Fun!

# %% [markdown]
# **Answer:**

# %% [markdown]
# To get fun, I will do some exploration of the data by these way:

# %% [markdown]
# ### Inspect The Corellation of 'general_squad_size' and 'general_squad_average_age'

# %%
# Create scatter plot
fig, ax = plt.subplots(figsize=(10,10))

sns.scatterplot(data = dataset, x = "general_squad_average_age", 
                y = "general_squad_size", s = 200, ax = ax,
                hue = dataset['Team']).set(title = 'Squad Size vs Age')
# Out:
# [Text(0.5, 1.0, 'Squad Size vs Age')]

# %% [markdown]
# ### Get The Team Squad of The Team

# %%
# Check the bar plot
sns.barplot(x = 'general_squad_size',
            y = 'Team',
            data = dataset).set(title = 'Team Squad Size')
# Out:
# [Text(0.5, 1.0, 'Team Squad Size')]

# %% [markdown]
# ### Get The Team Red Card Achievement

# %%
# Check the bar plot
sns.barplot(x = 'general_card_red',
            y = 'Team',
            data = dataset).set(title = 'Team Red Card Achievement')
# Out:
# [Text(0.5, 1.0, 'Team Red Card Achievement')]

# %% [markdown]
# ### Inspect The Corellation of Attacking Aspects

# %%
#Check the correlation
sns.heatmap(attack_dataset_fix.corr()).set(title = 'Correlation of Attacking Factors')
# Out:
# [Text(0.5, 1.0, 'Correlation of Attacking Factors')]

# %% [markdown]
# ### Inspect The Corellation of Defence Aspects

# %%
#Check the correlation
sns.heatmap(defence_dataset_fix.corr()).set(title = 'Correlation of Defending Factors')
# Out:
# [Text(0.5, 1.0, 'Correlation of Defending Factors')]
